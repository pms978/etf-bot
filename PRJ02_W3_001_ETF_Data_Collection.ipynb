# %% [markdown]
# #  추천 시스템 - ETF 데이터 수집 및 전처리
#
#
# ---

# %% [markdown]
# ## 환경 설정 및 준비

# %% [markdown]
# `(1) Env 환경변수`

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# `(2) 기본 라이브러리`

# %%
import os
from glob import glob

from pprint import pprint
import json

# %% [markdown]
# ## ETF 데이터 수집
#
# - CSV 다운로드
# - http://data.krx.co.kr/contents/MDC/MDI/mdiLoader/index.cmd?menuId=MDC020103010901

# %%
import pandas as pd
import numpy as np

etf_list = pd.read_csv('data/etf_list.csv', encoding='cp949')
etf_list.head()
# Out:
#      종목코드                    종목명         상장일       분류체계     운용사  수익률(최근 1년)  \
# 0  466400  1Q 25-08 회사채(A+이상)액티브  2023/09/19  채권-회사채-단기  하나자산운용        4.52
# 1  491610         1Q CD금리액티브(합성)  2024/09/24         기타  하나자산운용        0.00
# 2  451060             1Q K200액티브  2023/01/31    주식-시장대표  하나자산운용       -3.66
# 3  463290            1Q 단기금융채액티브  2023/08/03   채권-혼합-단기  하나자산운용        4.01
# 4  479080             1Q 머니마켓액티브  2024/04/02   채권-혼합-단기  하나자산운용        0.00
#
#                               기초지수  추적오차         순자산총액   괴리율   변동성     복제방법  \
# 0  KIS 2025-08만기형 크레딧 A+이상 지수(총수익)  0.11  111916276404  0.03  매우낮음  실물(액티브)
# 1                KIS 하나 CD금리 총수익지수  0.05  316206006696  0.02  매우낮음  합성(액티브)
# 2                          코스피 200  0.77   99754348820 -0.01    높음  실물(액티브)
# 3                  MK 머니마켓 지수(총수익)  0.05  252717462257  0.00  매우낮음  실물(액티브)
# 4               KIS-하나 MMF 지수(총수익)  0.06  308255065986 -0.01  매우낮음  실물(액티브)
#
#     총보수           과세유형
# 0  0.10  배당소득세(보유기간과세)
# ...

# %%
etf_list.tail()
# Out:
#        종목코드                     종목명         상장일      분류체계       운용사  \
# 925  429870           히어로즈 리츠이지스액티브  2022/05/24    부동산-리츠  키움투자자산운용
# 926  476450            히어로즈 머니마켓액티브  2024/02/29  채권-혼합-단기  키움투자자산운용
# 927  460270  히어로즈 미국달러SOFR금리액티브(합성)  2023/06/20        기타  키움투자자산운용
# 928  459790        히어로즈 미국성장기업30액티브  2023/06/27   주식-시장대표  키움투자자산운용
# 929  454780     히어로즈 종합채권(AA-이상)액티브  2023/04/11  채권-혼합-중기  키움투자자산운용
#
#      수익률(최근 1년)                                     기초지수  추적오차         순자산총액  \
# 925       -4.51                            iSelect 리츠 지수  3.07    3763127456
# 926        0.00                      KIS-키움 MMF지수(총수익지수)  0.06  327428123675
# 927       16.59  Solactive SOFR Daily Total Return Index  0.09    9885129694
# 928       44.70             MSCI USA Index(Price Return)  6.44   13371801852
# 929        7.56              KIS 종합 채권시장지수(AA-이상)(총수익지수)  0.24  338847308716
#
#       괴리율   변동성     복제방법    총보수               과세유형
# ...

# %%
etf_list.shape
# Out:
# (930, 14)

# %%
etf_list[etf_list['종목코드'] == '466400']
# Out:
#      종목코드                    종목명         상장일       분류체계     운용사  수익률(최근 1년)  \
# 0  466400  1Q 25-08 회사채(A+이상)액티브  2023/09/19  채권-회사채-단기  하나자산운용        4.52
#
#                               기초지수  추적오차         순자산총액   괴리율   변동성     복제방법  \
# 0  KIS 2025-08만기형 크레딧 A+이상 지수(총수익)  0.11  111916276404  0.03  매우낮음  실물(액티브)
#
#    총보수           과세유형
# 0  0.1  배당소득세(보유기간과세)

# %%
strIsurCd = '45979'
etf_url = f"https://kind.krx.co.kr/disclosure/etfisudetail.do?method=searchEtfIsuSummary&strIsurCd={strIsurCd}"

etf_url
# Out:
# 'https://kind.krx.co.kr/disclosure/etfisudetail.do?method=searchEtfIsuSummary&strIsurCd=45979'

# %% [markdown]
# ## Crawl4AI
#
# - LLM, AI 에이전트, 데이터 파이프라인을 위한 **고성능 웹 크롤링** 솔루션 제공
#
# - **오픈소스** 기반으로 실시간 성능과 유연한 구현이 가능
#
# - https://github.com/unclecode/crawl4ai?tab=readme-ov-file
#
# - 설치 방법:
#     ```bash
#     # 기본 설치 - 코어 라이브러리만 설치
#     pip install crawl4ai
#     uv add crawl4ai
#
#     # 초기 설정 - Playwright 브라우저 설치 및 환경 점검
#     (uv run) crawl4ai-setup
#
#     # 진단 도구 - 시스템 호환성 확인
#     (uv run) crawl4ai-doctor
#     ```

# %% [markdown]
# ### 1) Jupyter 환경 설정
#
# - `nest_asyncio`는 Jupyter에서 이미 실행 중인 이벤트 루프 위에 중첩된 이벤트 루프를 실행할 수 있게 해주는 패키지
#
# - Jupyter Notebook 에서 asyncio 를 사용할 때, 이 코드를 실행하면 에러가 발생하지 않음

# %%
# Jupyter Notebook 에서 asyncio 를 사용할 때, 이 코드를 실행하면 에러가 발생하지 않음 (MacOS, Linux 환경)
import nest_asyncio
nest_asyncio.apply()

# %%
# # Jupyter Notebook 에서 asyncio 를 사용할 때, 이 코드를 실행하면 에러가 발생하지 않음 (Windows용)
import asyncio
import sys

# 이벤트 루프 정책 변경 (Windows용)
if sys.platform == 'win32':
    asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())
    
# 새 이벤트 루프 생성 및 설정
loop = asyncio.new_event_loop()
asyncio.set_event_loop(loop)

# nest_asyncio 적용
import nest_asyncio
nest_asyncio.apply(loop)

# %% [markdown]
# ### 2) **기본 크롤링**
#
# - `BrowserConfig`와 `CrawlerRunConfig` 클래스 기본값 설정을 사용

# %%
import asyncio
from crawl4ai import AsyncWebCrawler, BrowserConfig, CrawlerRunConfig

async def main():
    """ 
    크롤링 실행 함수
    """
    browser_config = BrowserConfig()  # 브라우저 설정
    run_config = CrawlerRunConfig()   # 크롤러 실행 설정

    async with AsyncWebCrawler(config=browser_config) as crawler:   # 크롤러 객체 생성
        result = await crawler.arun(
            url=etf_url,
            config=run_config   # 크롤러 실행 설정
        )
        
    return result


# 크롤링 실행 및 결과 출력
#result = asyncio.run(main())  # asyncio.run() 사용 (리눅스)
result = loop.run_until_complete(main())  # 새 이벤트 루프에서 실행 (윈도우)
print(result.markdown)  # 크롤링 결과 (정제된 markdown 출력)
# Out:
# [INIT].... → Crawl4AI 0.9.0
# [FETCH]... ↓ https://kind.krx.co.kr/disclosure/etfisudetail.do?method=searchEtfIsuSummary&strIsurCd=45979         | ✓ | ⏱: 1.53s
# [SCRAPE].. ◆ https://kind.krx.co.kr/disclosure/etfisudetail.do?method=searchEtfIsuSummary&strIsurCd=45979         | ✓ | ⏱: 0.08s
# [COMPLETE] ● https://kind.krx.co.kr/disclosure/etfisudetail.do?method=searchEtfIsuSummary&strIsurCd=45979         | ✓ | ⏱: 1.66s
# # 키움 KIWOOM 미국성장기업30액티브증권상장지수투자신탁[주식]
#   * [상품개요(ETF)](https://kind.krx.co.kr/disclosure/etfisudetail.do?method=searchEtfIsuSummary&strIsurCd=45979 "상품개요\(ETF\)")
#
#
# ## 상품 개요
# 목록
# | 한글명  |  KIWOOM 미국성장기업30액티브   | 영문명  |  KIWOOM US Growth 30 Active   |
# | --- | --- | --- | --- |
# | 표준코드  |  KR7459790002   | 종목코드  |  459790   |
# | 상장일  |  2023-06-27   | 펀드형태  |  수익증권형   |
# | 기초지수명  |  MSCI USA Index(Price Return)   | 추적배수  |  일반 (1)   |
# | 자산운용사  |  키움투자자산운용(주)   | 지정참가회사(AP)  |  키움증권, 삼성증권, DB금융투자   |
# ...

# %% [markdown]
# ### 3) **CrawlResult 응답 객체**
#
# - 크롤링된 URL, HTML, 성공 여부 등 기본 정보 포함
#
# - **cleaned_html**와 **markdown** 필드로 정제된 데이터 접근 가능
#
# - **extracted_content**를 통해 구조화된 형태의 추출 데이터 확인

# %%
result.model_dump()
# Out:
# {'url': 'https://kind.krx.co.kr/disclosure/etfisudetail.do?method=searchEtfIsuSummary&strIsurCd=45979',
# ...

# %%
# 크롤링 성공 여부 확인
result.success
# Out:
# True

# %%
# HTML 접근
print(result.html[:100])
# Out:
# <!DOCTYPE html><html lang="ko"><head>
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta ht

# %%
# 정제된 HTML 출력
print(result.cleaned_html[:100])
# Out:
# <html>
# <head>
# <title>대한민국 대표 기업공시채널 KIND</title>
# <!--[if lt IE 9]>
# <script type="text/javascript" sr

# %%
# 마크다운 변환 결과 (정제된)
print(result.markdown)
# Out:
# # 키움 KIWOOM 미국성장기업30액티브증권상장지수투자신탁[주식]
#   * [상품개요(ETF)](https://kind.krx.co.kr/disclosure/etfisudetail.do?method=searchEtfIsuSummary&strIsurCd=45979 "상품개요\(ETF\)")
#
#
# ## 상품 개요
# 목록
# | 한글명  |  KIWOOM 미국성장기업30액티브   | 영문명  |  KIWOOM US Growth 30 Active   |
# | --- | --- | --- | --- |
# | 표준코드  |  KR7459790002   | 종목코드  |  459790   |
# | 상장일  |  2023-06-27   | 펀드형태  |  수익증권형   |
# | 기초지수명  |  MSCI USA Index(Price Return)   | 추적배수  |  일반 (1)   |
# | 자산운용사  |  키움투자자산운용(주)   | 지정참가회사(AP)  |  키움증권, 삼성증권, DB금융투자   |
# | 총보수(%)  |  0.76   | 회계기간  |  매년 1월 1일부터 12월 31일까지. 단, 최초 회계기간은 최초설정일로부터 당해연도 12월 31일까지   |
# | 과세유형  |  배당소득세(보유기간과세)   | 분배금 지급일  |  1월, 4월, 7월, 10월 마지막 영업일 및 회계기간 종료일(다만, 회계기간 종료일이 영업일이 아닌 경우 그 직전 영업일)   |
# | 홈페이지  |  <http://www.kosef.co.kr>  |
# ## 유형 정보
# 목록
# | 기초 시장  |  (해외)
# (북미)
# (미국)   | 기초 자산  |  (주식)
# (시장대표) / (-)
# (-) / (-)   |
# | --- | --- | --- | --- |
# ## 상품 설명
# 목록
# | 기본 정보  |
# ```
# ...

# %%
# 구조화된 데이터 (Optional)
if result.extracted_content:
    data = json.loads(result.extracted_content)
    print(data)

# %% [markdown]
# ### 4) **BrowserConfig 설정**
#
# - **BrowserConfig**로 브라우저 타입, 헤드리스 모드, 뷰포트 크기 등 **기본 설정** 관리
#
# - **프록시 설정**과 **디버깅 옵션**을 통한 고급 크롤링 환경 구성
#
# - **AsyncWebCrawler** 클래스와 연동하여 비동기 크롤링 실행

# %%
import asyncio
from crawl4ai import AsyncWebCrawler, BrowserConfig, CrawlerRunConfig

# 기본 설정
base_config = BrowserConfig(
    browser_type="chromium",  # 브라우저 엔진 선택
    viewport_width=1080,     # 뷰포트 크기
    viewport_height=600,
    text_mode=True,          # 텍스트 모드 (이미지 비활성화)
    use_persistent_context=True,  # 세션을 유지
    headless=True,           # 헤드리스 모드 실행
    enable_stealth=True,     # 스텔스 모드 활성화로 봇 탐지 우회
)

# 디버깅용 설정
debug_config = base_config.clone(
    headless=False,  # 헤드리스 모드 비활성화
    verbose=True     # 디버깅용 로그 출력
) 

# 프록시 설정 (필요 시 적절한 프록시 서버 구성)
proxy_config = {
    "server": "http://proxy.example.com:8080",
    "username": "user",
    "password": "pass"
}

proxy_config = base_config.clone(
    proxy_config=proxy_config,  
)

# 크롤러 실행 설정
run_config = CrawlerRunConfig()   

async def extract_by_url(url , browser_config: BrowserConfig, run_config: CrawlerRunConfig):
    """ 
    크롤링 실행 함수
    """

    async with AsyncWebCrawler(config=browser_config) as crawler:   # 크롤러 객체 생성
        result = await crawler.arun(
            url=url,
            config=run_config   # 크롤러 실행 설정
        )
        
    return result


# 크롤링 실행 및 결과 출력
#result = asyncio.run(extract_by_url(etf_url, base_config, run_config))
result = loop.run_until_complete(extract_by_url(etf_url, base_config, run_config))
print(result.success)  # 크롤링 성공 여부
print(result.markdown)  # 크롤링 결과 (정제된 markdown 출력)
# Out:
# [INIT].... → Crawl4AI 0.9.0
# [FETCH]... ↓ https://kind.krx.co.kr/disclosure/etfisudetail.do?method=searchEtfIsuSummary&strIsurCd=45979         | ✓ | ⏱: 1.02s
# [SCRAPE].. ◆ https://kind.krx.co.kr/disclosure/etfisudetail.do?method=searchEtfIsuSummary&strIsurCd=45979         | ✓ | ⏱: 0.03s
# [COMPLETE] ● https://kind.krx.co.kr/disclosure/etfisudetail.do?method=searchEtfIsuSummary&strIsurCd=45979         | ✓ | ⏱: 1.08s
# True
# # 키움 KIWOOM 미국성장기업30액티브증권상장지수투자신탁[주식]
#   * [상품개요(ETF)](https://kind.krx.co.kr/disclosure/etfisudetail.do?method=searchEtfIsuSummary&strIsurCd=45979 "상품개요\(ETF\)")
#
#
# ## 상품 개요
# 목록
# | 한글명  |  KIWOOM 미국성장기업30액티브   | 영문명  |  KIWOOM US Growth 30 Active   |
# | --- | --- | --- | --- |
# | 표준코드  |  KR7459790002   | 종목코드  |  459790   |
# | 상장일  |  2023-06-27   | 펀드형태  |  수익증권형   |
# | 기초지수명  |  MSCI USA Index(Price Return)   | 추적배수  |  일반 (1)   |
# | 자산운용사  |  키움투자자산운용(주)   | 지정참가회사(AP)  |  키움증권, 삼성증권, DB금융투자   |
# ...

# %% [markdown]
# ### 5) **CrawlerRunConfig 설정**
#
# - 단어 수 제한, 추출 전략, 캐시 설정 등 **크롤링 옵션** 관리
#
# - **js_code**와 **wait_for** 옵션으로 동적 콘텐츠 처리 가능
#
# - **screenshot**과 **rate_limiting** 기능으로 크롤링 과정 제어
#
# - **기본 구조**:
#
#     ```python
#     class CrawlerRunConfig:
#         def __init__(
#             word_count_threshold=200,      # 컨텐츠 최소 단어 수
#             extraction_strategy=None,      # 데이터 추출 전략
#             cache_mode=None,               # 캐시 설정
#             js_code=None,                  # 실행할 JS 코드
#             wait_for=None,                 # 대기 조건
#             screenshot=False,              # 스크린샷 캡처
#             enable_rate_limiting=False     # 속도 제한 활성화
#         )
#     ```

# %% [markdown]
# `(1) 기본 추출 설정`

# %%
from crawl4ai import AsyncWebCrawler, BrowserConfig, CrawlerRunConfig, CacheMode

run_config = CrawlerRunConfig(
    cache_mode=CacheMode.ENABLED,   # 캐시 활성화
    word_count_threshold=200,       # 컨텐츠 블록의 최소 단어 수 기준 설정 (짧은 문단이나 항목이 많은 사이트는 기준값을 낮춰야 함)
)

# 크롤링 실행 및 결과 출력
#result = asyncio.run(extract_by_url(etf_url, base_config, run_config))
result = loop.run_until_complete(extract_by_url(etf_url, base_config, run_config))
print(result.success)  # 크롤링 성공 여부
print(result.markdown)  # 크롤링 결과 (정제된 markdown 출력)
# Out:
# [INIT].... → Crawl4AI 0.9.0
# [FETCH]... ↓ https://kind.krx.co.kr/disclosure/etfisudetail.do?method=searchEtfIsuSummary&strIsurCd=45979         | ✓ | ⏱: 1.07s
# [SCRAPE].. ◆ https://kind.krx.co.kr/disclosure/etfisudetail.do?method=searchEtfIsuSummary&strIsurCd=45979         | ✓ | ⏱: 0.01s
# [COMPLETE] ● https://kind.krx.co.kr/disclosure/etfisudetail.do?method=searchEtfIsuSummary&strIsurCd=45979         | ✓ | ⏱: 1.16s
# True
# # 키움 KIWOOM 미국성장기업30액티브증권상장지수투자신탁[주식]
#   * [상품개요(ETF)](https://kind.krx.co.kr/disclosure/etfisudetail.do?method=searchEtfIsuSummary&strIsurCd=45979 "상품개요\(ETF\)")
#
#
# ## 상품 개요
# 목록
# | 한글명  |  KIWOOM 미국성장기업30액티브   | 영문명  |  KIWOOM US Growth 30 Active   |
# | --- | --- | --- | --- |
# | 표준코드  |  KR7459790002   | 종목코드  |  459790   |
# | 상장일  |  2023-06-27   | 펀드형태  |  수익증권형   |
# | 기초지수명  |  MSCI USA Index(Price Return)   | 추적배수  |  일반 (1)   |
# | 자산운용사  |  키움투자자산운용(주)   | 지정참가회사(AP)  |  키움증권, 삼성증권, DB금융투자   |
# ...

# %% [markdown]
# `(2) 추출 전략`
#
# - 참조 문서: https://docs.crawl4ai.com/core/content-selection/
#
# - 대상 페이지: https://news.ycombinator.com/newest
#
# - robots.txt: https://www.ycombinator.com/robots.txt

# %%
news_url = "https://news.ycombinator.com/newest"
news_url
# Out:
# 'https://news.ycombinator.com/newest'

# %%
from crawl4ai import AsyncWebCrawler, BrowserConfig, CrawlerRunConfig, CacheMode

run_config = CrawlerRunConfig(
    css_selector="#bigbox",         # 크롤링 대상 컨텐츠 선택자
    word_count_threshold=10,             # 컨텐츠 블록의 최소 단어 수 기준 설정
    excluded_tags=["nav", "footer"],     # 제외할 태그 설정
    exclude_external_links=True,         # 외부 링크 제외 설정
    exclude_social_media_links=True,     # 소셜 미디어 링크 제외 설정
    exclude_domains=["ads.com", "spammytrackers.net"],   # 제외할 도메인 설정
    exclude_external_images=True,         # 외부 이미지 제외 설정
    cache_mode=CacheMode.BYPASS           # 캐시 비활성화
)

# 크롤링 실행 및 결과 출력
#result = asyncio.run(extract_by_url(news_url, base_config, run_config))
result = loop.run_until_complete(extract_by_url(news_url, base_config, run_config))
print(result.success)  # 크롤링 성공 여부
print(result.markdown)  # 크롤링 결과 (정제된 markdown 출력)
# Out:
# [INIT].... → Crawl4AI 0.9.0
# [FETCH]... ↓ https://news.ycombinator.com/newest                                                                  | ✓ | ⏱: 1.16s
# [SCRAPE].. ◆ https://news.ycombinator.com/newest                                                                  | ✓ | ⏱: 0.16s
# [COMPLETE] ● https://news.ycombinator.com/newest                                                                  | ✓ | ⏱: 1.36s
# True
# |
#  | 1.  | [](https://news.ycombinator.com/vote?id=48816381&how=up&goto=newest)  | [Bank of England sees growing risks to financial stability from AI](https://www.reuters.com/business/finance/bank-england-sees-growing-risks-financial-stability-ai-2026-07-07/) ([reuters.com](https://news.ycombinator.com/from?site=reuters.com))  |
# | --- | --- | --- |
# ...

# %%
# CSS 기반 추출 전략
from crawl4ai.extraction_strategy import JsonCssExtractionStrategy

news_schema = {
    "name": "HN Stories",
    "baseSelector": "tr.athing submission",
    "fields": [
        { 
            "name": "title",
            "selector": "td.title span.titleline a:first-child",
            "type": "text"
        },
        {
            "name": "url",
            "selector": "td.title span.titleline a:first-child",
            "type": "attribute", 
            "attribute": "href"
        },
        {
            "name": "rank",
            "selector": "td.title span.rank",
            "type": "text",
            "transform": lambda x: int(x.strip("."))
        }
    ]
}

extraction_config = CrawlerRunConfig(
    extraction_strategy=JsonCssExtractionStrategy(news_schema),
    cache_mode=CacheMode.BYPASS  # 항상 최신 데이터 가져오기
)


# 크롤링 실행 및 결과 출력
#result = asyncio.run(extract_by_url(news_url, base_config, extraction_config))
result = loop.run_until_complete(extract_by_url(news_url, base_config, run_config))

# 구조화된 데이터 (Optional)
if result.extracted_content:
    data = json.loads(result.extracted_content)
    print(data)
# Out:
# [INIT].... → Crawl4AI 0.9.0
# [FETCH]... ↓ https://news.ycombinator.com/newest                                                                  | ✓ | ⏱: 1.22s
# [SCRAPE].. ◆ https://news.ycombinator.com/newest                                                                  | ✓ | ⏱: 0.10s
# [COMPLETE] ● https://news.ycombinator.com/newest                                                                  | ✓ | ⏱: 1.34s

# %%
eval(result.extracted_content)[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 eval(result.extracted_content)[0]
#
# TypeError: eval() arg 1 must be a string, bytes or code object

# %%
# 네이버 뉴스

news_url = "https://n.news.naver.com/article/654/0000103393?cds=news_media_pc&type=breakingnews"
news_url
# Out:
# 'https://n.news.naver.com/article/654/0000103393?cds=news_media_pc&type=breakingnews'

# %%
import os
import json
import asyncio
from pydantic import BaseModel, Field
from crawl4ai import AsyncWebCrawler, CrawlerRunConfig, CacheMode
from crawl4ai.async_configs import LLMConfig 
from crawl4ai.extraction_strategy import LLMExtractionStrategy

# 데이터 모델 정의
class NaverNewsArticle(BaseModel):
    title: str = Field(description="기사 제목")
    published_date: str = Field(description="발행일")
    author: str = Field(description="기자 이름") 
    content: str = Field(description="기사 본문")


async def extract_naver_news(news_url):
    # LLM 추출 전략 설정
    strategy = LLMExtractionStrategy(
        llm_config=LLMConfig(
            provider="openai/gpt-4.1-mini",
            api_token=os.getenv("OPENAI_API_KEY"),
            ),
        schema=NaverNewsArticle.model_json_schema(),
        extraction_type="schema",
        instruction="""
        네이버 뉴스 기사에서 다음 정보를 추출하세요:
        - title: 기사 제목
        - published_date: 발행일시 
        - author: 기자 이름
        - content: 기사 본문
        """
    )

    config = CrawlerRunConfig(
        exclude_external_links=True,
        extraction_strategy=strategy,
        cache_mode=CacheMode.BYPASS,
        magic=True
    )

    async with AsyncWebCrawler(config=base_config) as crawler:
        result = await crawler.arun(url=news_url, config=config)

        print(result.extracted_content)
        
        if result.extracted_content:
            article = json.loads(result.extracted_content)
            return article
        return None

# 실행
news_url = "https://n.news.naver.com/article/654/0000103393?cds=news_media_pc&type=breakingnews"
#article = asyncio.run(extract_naver_news(news_url)) # asyncio.run() 사용
article = loop.run_until_complete(extract_naver_news(news_url))  #  윈도우 기준


print(article)
# Out:
# [INIT].... → Crawl4AI 0.9.0
# [FETCH]... ↓ https://n.news.naver.com/article/654/0000103393?cds=news_media_pc&type=breakingnews                  | ✓ | ⏱: 2.52s
# [SCRAPE].. ◆ https://n.news.naver.com/article/654/0000103393?cds=news_media_pc&type=breakingnews                  | ✓ | ⏱: 0.72s
# [EXTRACT]. ■ https://n.news.naver.com/article/654/0000103393?cds=news_media_pc&type=breakingnews                  | ✓ | ⏱: 38.33s
# [COMPLETE] ● https://n.news.naver.com/article/654/0000103393?cds=news_media_pc&type=breakingnews                  | ✓ | ⏱: 41.63s
# [
#     {
#         "title": "[속보] 전국 곳곳 대설 특보…강원내륙·산지 최대 30㎝ 폭설",
#         "published_date": "2025.01.27. 오전 8:57",
#         "author": "이채윤 기자",
# ...

# %%
pprint(article[0]['content'])
# Out:
# ('임시공휴일이자 월요일인 27일 전국에 눈·비가 쏟아졌다가 잦아들기를 반복하겠다. 길게는 설날까지 이어질 전망이다. 오전 7시 30분 현재 '
#  '동해안 일부를 제외한 전국에 눈 또는 비가 내리고 있다. 북쪽에서 찬 공기가 남하해 들어오면서 비가 오는 지역은 남해안 일부로 줄고 '
#  '대부분 지역에선 눈이 내리고 있다. 제주 한라산엔 오전 7시 기준 최근 24시간 내 10㎝ 넘는 눈이 내려 쌓였다. 강원 철원군 '
#  '임남면이나 충남 계룡산, 인천 강화군 양도면 등은 24시간 신적설(일정 시간에 새로 내려 쌓인 눈의 양)이 5㎝가 넘는다. 설 전날인 '
#  '28일까지 강원내륙·산지, 수도권, 서해5도, 전북동부, 제주산지엔 10∼20㎝ 눈이 쌓이겠다. 강원내륙·산지와 전북동부·제주산지엔 '
#  '30㎝ 이상, 경기남부와 경기북동부엔 25㎝ 이상, 충청엔 최대 20㎝ 이상 눈이 쌓일 수 있다. 광주·전남(동부남해안 제외)·전북서부엔 '
#  '5∼10㎝(최대 15㎝ 이상), 경북북부내륙·경북북동산지·경남서부내륙엔 3∼10㎝(최대 15㎝ 이상), 제주중산간엔 3∼10㎝, '
#  '대구·경북남서내륙·울릉도·독도엔 3∼8㎝ 적설이 예상된다. 나머지 지역에는 1∼5㎝(울산은 1㎝ 미만) 정도 쌓이겠다. 경기남서부와 '
#  '강원내륙·산지, 충청, 호남, 경북서부·북동내륙, 경남서부내륙, 제주는 29일 들어서도 오후까지 눈·비가 이어질 전망이다. 이들 지역엔 '
#  '29일에만 3∼8㎝ 또는 1∼5㎝ 눈이 추가로 적설될 것으로 보인다. 중부지방과 전북, 제주산지에는 27일 오후까지 눈이 시간당 '
#  '3∼5㎝, 전북 외 남부지방에는 시간당 1∼3㎝씩 쏟아질 수 있다. 일부는 1시간 동안 내리는 눈의 양이 5㎝ 안팎에 달할 수 있다. '
#  '28일 새벽부터 오후까지에는 전국(수도권·강원내륙·강원산지·호남은 27일 밤부터)에 시간당 1∼3㎝(최대 5㎝ 안팎)의 폭설이 예상된다. '
# ...

# %% [markdown]
# ---
#
# ## [실습] **ETF 상세정보 수집**
#
# - 다음 ETF 상세 페이지에서 다음 항목을 수집하는 함수를 작성합니다.
# - 대상 필드:
#     - '한글명', '영문명', '종목코드', '상장일', '펀드형태', '기초지수명', '추적배수', '자산운용사',
#     - '지정참가회사(AP)', '총보수(%)', '회계기간', '과세유형', '분배금 지급일', '홈페이지',
#     - '기초 시장', '기초 자산', '기본 정보', '투자유의사항'
#
# - 모두 5개의 ETF 종목에 대한 정보를 수집하여 csv 파일로 저장합니다.
#
# - **Hint**:
#     - crawl4ai 사용하여 각 ETF 상세 페이지의 HTML 소스코드를 추출 (종목코드: 5자리 숫자에 유의)
#     - pandas.read_html() 함수를 사용하여 HTML 소스코드에서 테이블 데이터를 추출

# %%
import asyncio
import pandas as pd
from crawl4ai import AsyncWebCrawler, CrawlerRunConfig, CacheMode

# 1. 수집할 ETF 종목코드 정의 (5자리 숫자 포맷, 예: '06950' 등)
# 종목코드가 5자리(예: 06950 -> 코드가 숫자형일 때 앞에 0이 사라질 수 있으므로 문자열 처리 권장)
etf_tickers = ["069500", "102110", "148020", "252670", "122630"]  # 예시 5개 종목코드 (국내 ETF는 보통 6자리이나, 해외 혹은 플랫폼에 따라 5자리일 경우에 맞춰 수정하세요)

# 2. 크롤링 및 데이터 파싱 함수 정의
async def crawl_etf_data(tickers):
    all_etf_data = []
    
    # 캐시를 무시하고 최신 페이지를 가져오도록 설정
    config = CrawlerRunConfig(cache_mode=CacheMode.BYPASS)
    
    async with AsyncWebCrawler() as crawler:
        for ticker in tickers:
            # 5자리 숫자에 맞게 종목코드 포맷 확인 (예: '00350' 처럼 5자리로 채우기)
            # ticker_str = str(ticker).zfill(5)
            ticker_str = str(ticker) # 예제에서는 6자리로 진행
            
            # 대상 ETF 상세페이지 URL (실제 분석할 페이지의 URL 포맷에 맞게 도메인 변경 필요)
            url = f"https://kind.krx.co.kr/disclosure/etfisudetail.do?method=searchEtfIsuSummary&strIsurCd={ticker_str}"
            
            print(f"Crawling: {url} ...")
            
            # 페이지 크롤링 수행
            result = await crawler.arun(url=url, config=config)
            
            if result.success:
                html_content = result.html
                
                # pandas.read_html()로 HTML 내 모든 table 태그 추출
                try:
                    tables = pd.read_html(html_content)
                    
                    # 수집하려는 정보(한글명, 영문명, 기초지수 등)가 포함된 테이블을 찾아 가공
                    # 아래는 임시 딕셔너리로 추출한 예시입니다. 
                    # 실제 대상 페이지의 테이블 인덱스와 구조(행/열 이름)에 맞게 추출 로직을 작성해야 합니다.
                    etf_info = {
                        "종목코드": ticker_str,
                        # "한글명": tables[0].loc[...],  # 테이블 위치에 맞춰 인덱싱
                        # "영문명": tables[0].loc[...],
                        # "기초지수명": tables[1].loc[...]
                    }
                    
                    # (예시용) tables가 정상적으로 읽혔는지 개수 확인
                    print(f"Successfully extracted {len(tables)} tables for ticker {ticker_str}")
                    
                    # 추출한 데이터 임시 저장
                    all_etf_data.append(etf_info)
                    
                except Exception as e:
                    print(f"Error parsing tables for {ticker_str}: {e}")
            else:
                print(f"Failed to crawl {ticker_str}: {result.error_message}")
                
            # 디버깅/차단 방지를 위한 잠시 대기
            await asyncio.sleep(1)
            
    return all_etf_data

# %%
# 실행

# 3. Jupyter Notebook 내에서 비동기 함수 직접 실행 (await 사용)
# Jupyter 환경에서는 이벤트 루프가 이미 실행 중이므로 asyncio.run() 대신 await을 사용합니다.
data_list = loop.run_until_complete(crawl_etf_data(etf_tickers))

# 4. Pandas DataFrame으로 변환 및 CSV 저장
df = pd.DataFrame(data_list)
print(df)

# CSV 파일 저장
# df.to_csv("etf_details.csv", index=False, encoding="utf-8-sig")
# Out:
# [INIT].... → Crawl4AI 0.9.0
# Crawling: https://finance.naver.com/item/main.naver?code=069500 ...
# [FETCH]... ↓ https://finance.naver.com/item/main.naver?code=069500                                                | ✓ | ⏱: 2.26s
# [SCRAPE].. ◆ https://finance.naver.com/item/main.naver?code=069500                                                | ✓ | ⏱: 0.21s
# [COMPLETE] ● https://finance.naver.com/item/main.naver?code=069500                                                | ✓ | ⏱: 2.51s
# Error parsing tables for 069500: [Errno 2] No such file or directory: <html lang="ko" data-useragent="Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 Chrome/116.0.0.0 Safari/537.36"><head>
#
#
#
# 		<title>KODEX 200 : Npay 증권</title>
#
#
#
#
#
#
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#
# <meta http-equiv="Content-Script-Type" content="text/javascript">
# <meta http-equiv="Content-Style-Type" content="text/css">
# ...
